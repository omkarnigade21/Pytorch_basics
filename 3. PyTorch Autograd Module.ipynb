# %%
# importing torch library
import torch

# %%
# initializing a 2d tensor
a = torch.tensor([[1,1], [1,1]], dtype=torch.float)
a
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
# performing operations on the tensor
b = a + 5
print(b)
# Out:
# tensor([[6., 6.],
#         [6., 6.]])

# %%
# performing another operation
c = b.mean()
print(c)
# Out:
# tensor(6.)

# %% [markdown]
# ### Operations we have applied
#
#
#
# 1. First of all, we added 5 to all the elements of this tensor
# 2. Then, we took the mean of that tensor
#
# We performed the following operations on a:
#
# b = a + 5
#
# c = mean(b) = Σ(a+5) / 4

# %% [markdown]
# ### Gradient of c with respect to a
#
# dc / da = dc/db * db / da = 1/4(1+0) * (1+0) = 1/4 = 0.25
#
# Similarly, we can compute for all elements of a

# %% [markdown]
# ## Automatic Differentiation

# %%
# initializing a 2d tensor and setting requires_grad as
# requires_grad = True used to calculate differentiation of any function wrt a

a = torch.tensor([[1,1], [1,1]], dtype= torch.float, requires_grad=True)
a
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)

# %%
# performing operations on the tensor
b = a + 5
c = b.mean()
print(b)
print(c)
# Out:
# tensor([[6., 6.],
#         [6., 6.]], grad_fn=<AddBackward0>)
# tensor(6., grad_fn=<MeanBackward0>)

# %%
# back propagating
# gives rate of change of c with respect to backward variables.(Need to keep requires_grad = True for those backward wariables)
# Here backward variables for c are b and a as c = f(b), b = g(a)
c.backward()

# %%
# calculated gradients
print(a.grad)
# Out:
# tensor([[0.5000, 0.5000],
#         [0.5000, 0.5000]])
